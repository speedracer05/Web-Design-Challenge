# %%
import pandas as pd
import os

# %%
# file = pandas.read_csv("./Resources/cities.csv", encoding="utf-8", nrows=10)
csv_path = os.path.join('Resources', 'cities.csv')
cities_csv = pd.read_csv(csv_path, encoding="UTF-8", nrows=10)
cities_csv
# Out:
#    City_ID           City  Cloudiness Country             Date  Humidity  \
# 0        0      Mahébourg          75      MU  6/17/2021 17:59        94
# 1        1     Oranjestad          20      AW  6/17/2021 17:59        62
# 2        2    Grand Gaube          14      MU  6/17/2021 17:59        84
# 3        3         Hasaki          10      JP  6/17/2021 17:51        80
# 4        4   Puerto Ayora          75      EC  6/17/2021 17:51        83
# 5        5  Shahr-e Bābak           0      IR  6/17/2021 17:59        11
# 6        6           Lebu          11      CL  6/17/2021 17:51        66
# 7        7         Torbay          75      CA  6/17/2021 17:59        80
# 8        8        Rikitea          97      PF  6/17/2021 17:59        79
# 9        9           Baní          48      DO  6/17/2021 17:59        55
#
#        Lat       Lng  Max Temp  Wind Speed
# 0 -20.4081   57.7000     70.09        9.22
# 1  12.5240  -70.0270     89.55       21.85
# ...

# %%
# cities_csv.to_html("cities_table.html", index=False, classes=['table', 'table-striped', 'table-hover'])
cities_csv.to_html('cities_table.html', index=False, classes=['table', 'table-striped', 'table-hover'], encoding= 'utf-8')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-dd0b843cff87> in <module>()
#       1 # cities_csv.to_html("cities_table.html", index=False, classes=['table', 'table-striped', 'table-hover'])
# ----> 2 cities_csv.to_html('cities_table.html', index=False, classes=['table', 'table-striped', 'table-hover'], encoding= u'utf-8')
#
# TypeError: to_html() got an unexpected keyword argument 'encoding'
